# %%
import seaborn as sns

# %% [markdown]
# ## Count Plot

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.to_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=titanic, x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(data=titanic, x='class', palette='Oranges')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=titanic, x='class', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=titanic, x='class', hue='deck')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=titanic, y='class', hue='deck')
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
ax = sns.countplot(data=titanic, x='class', hue='who')
for element in ax.containers:
    ax.bar_label(element)

# %% [markdown]
# ## heatmap

# %%
ax = sns.countplot(data=titanic, x='who', hue='alive')
for element in ax.containers:
    ax.bar_label(element)

# %%
sns.heatmap(data=titanic[['fare']])
# Out:
# <Axes: >

# %%
data = [[99,15,85],
        [78,5,16],
        [56,2,5]]

# %%
sns.heatmap(data=data, annot=True)
# Out:
# <Axes: >

# %%
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
sns.heatmap(data=glue, annot=True)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
! pip install seaborn --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 279.3 kB/s eta 0:00:01
#    ---------- ---------------------------- 81.9/294.9 kB 459.5 kB/s eta 0:00:01
#    ------------------------------ --------- 225.3/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
sns.heatmap(glue, annot=True, linewidth=1, cmap='Blues')
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
glue.to_csv('glue.csv')

# %%
glue
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3
# ERNIE        75.5  92.3  93.9  97.3  75.2  92.6   97.8   93.0
# RoBERTa      67.8  90.8  92.3  95.4  74.3  88.2   96.7   92.2
# T5           71.6  92.2  92.8  96.9  75.1  92.8   97.5   93.1
